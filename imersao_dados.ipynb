# %% [markdown]
# # Aula 1 - Imersão de Dados

# %%
import pandas as pd

# %%
url_dados = (r"C:\Users\brnam\Analise-dados-env\Alura\dados\dados_experimentos.zip")

dados = pd.read_csv(url_dados, compression = "zip")

# %%
dados.head()
# Out:
#              id tratamento  tempo dose      droga     g-0     g-1     g-2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  com_droga     72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#       g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %%
dados.shape #linhas e colunas
# Out:
# (23814, 877)

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48], dtype=int64)

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['tempo'].value_counts()
# Out:
# 48    8250
# 72    7792
# 24    7772
# Name: tempo, dtype: int64

# %%
dados['droga'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 8bc88a3be       1
# e3fe7b417       1
# ef4e67d99       1
# 40b490d82       1
# 1a038f0f7       1
# Name: droga, Length: 3289, dtype: int64

# %%
# Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?

# %%
controle = dados[dados["tratamento"] == "com_controle"]

# %%
controle.droga.unique()
# Out:
# array(['cacb2b860'], dtype=object)

# %%
controle.droga.value_counts()
# Out:
# cacb2b860    1866
# Name: droga, dtype: int64

# %%
controle2 = dados[dados["tratamento"] == "com_droga"]

# %%
controle2.droga.unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
controle2.droga.value_counts()
# Out:
# 87d714366    718
# 9f80f3f77    246
# 8b87a7a83    203
# 5628cb3ee    202
# d08af5d4b    196
#             ...
# 8bc88a3be      1
# e3fe7b417      1
# ef4e67d99      1
# 40b490d82      1
# 1a038f0f7      1
# Name: droga, Length: 3288, dtype: int64

# %%
controle3 = dados[dados["tratamento"] == "com_controle"]

# %%
controle3.dose.value_counts()
# Out:
# D1    951
# D2    915
# Name: dose, dtype: int64

# %%
controle4 = dados[dados["tratamento"] == "com_droga"]

# %%
controle4.dose.value_counts()
# Out:
# D1    11196
# D2    10752
# Name: dose, dtype: int64

# %%
# "com_controle" se associa a apenas um tipo de droga, já "com_droga" se associa a vários tipos de drogas diferentes

# %%
# Desafio 02: Plotar as 5 últimas linhas da tabela

# %%
dados[-5:]
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# 23809 -0.1112 -0.5080 -0.4713  ...  0.1969  0.0262 -0.8121  0.3434  0.5372
# 23810 -0.3743  0.9905 -0.7178  ...  0.4286  0.4426  0.0423 -0.3195 -0.8086
# 23811  0.3109 -0.7389  0.5505  ...  0.5409  0.3755  0.7343  0.2807  0.4116
# 23812  0.4392  0.2044  0.8531  ... -0.1105  0.4258 -0.2012  0.1506  1.5230
# 23813 -0.1361  0.7952 -0.3611  ... -3.3890 -1.7450 -6.6300 -4.0950 -7.3860
#
#          c-95    c-96    c-97    c-98    c-99
# ...

# %%
# Desafio 03: Proporção das classes tratamento

# %%
dados.value_counts('tratamento', normalize=True)
# Out:
# tratamento
# com_droga       0.921643
# com_controle    0.078357
# dtype: float64

# %%
# Desafio 04: Quantas tipos de drogas foram investigados

# %%
dados['droga'].nunique()
# Out:
# 3289

# %%
# Desafio 05: Procurar na documentação o método query(pandas)

# %%
dados.query('tempo == 48').head()
# Out:
#              id tratamento  tempo dose      droga     g-0     g-1     g-2  \
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 7  id_0020d0484  com_droga     48   D1  8b87a7a83  0.2711  0.5133 -0.1327
# 8  id_00224bf20  com_droga     48   D1  952b76dfc -0.3014  0.5545 -0.2576
# 9  id_0023f063e  com_droga     48   D2  de7583071 -0.0630  0.2564 -0.5279
#
#       g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 7  2.5950  0.6980  ...  0.3230 -0.4140  0.2532  0.0513  0.8600  1.4250
# 8 -0.1390 -0.6487  ... -1.6470  0.2863  1.1070 -0.7735 -1.0280 -1.3070
# 9 -0.2541 -0.0182  ...  0.2201  0.5601 -0.3501 -1.4070 -0.1717 -1.1160
#
#      c-96    c-97    c-98    c-99
# 2 -0.6417 -0.2187 -1.4080  0.6931
# ...

# %%
# Desafio 06: Renomear as colunas tirando o hífen

# %%
dados.columns = dados.columns.str.replace('-', '')
dados.head()
# Out:
#              id tratamento  tempo dose      droga      g0      g1      g2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  com_droga     72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#        g3      g4  ...     c90     c91     c92     c93     c94     c95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#       c96     c97     c98     c99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %%
# ---

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tempo'].value_counts(normalize = True)
# Out:
# 48    0.346435
# 72    0.327202
# 24    0.326363
# Name: tempo, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
dados['tratamento'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='tratamento'>

# %%
dados['dose'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='dose'>

# %%
dados['tempo'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='tempo'>

# %%
dados['tempo'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
dados['g0'] > 0
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 23809     True
# 23810    False
# 23811     True
# 23812     True
# 23813    False
# Name: g0, Length: 23814, dtype: bool

# %%
dados[dados['g0'] > 0]
# Out:
#                  id    tratamento  tempo dose      droga      g0      g1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 6      id_001bd861f     com_droga     24   D2  746ca1f5a  2.0440  1.7000
# 7      id_0020d0484     com_droga     48   D1  8b87a7a83  0.2711  0.5133
# ...             ...           ...    ...  ...        ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  a28556d51  0.1420 -0.3696
# 23808  id_fff8c2444     com_droga     72   D1  6c3a459be  0.1608 -1.0500
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
#
#            g2      g3      g4  ...     c90     c91     c92     c93     c94  \
# ...

# %%
dados_filtrados = dados[dados['g0'] > 0]

# %%
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose      droga      g0      g1      g2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 6  id_001bd861f  com_droga     24   D2  746ca1f5a  2.0440  1.7000 -1.5390
# 7  id_0020d0484  com_droga     48   D1  8b87a7a83  0.2711  0.5133 -0.1327
#
#        g3      g4  ...     c90     c91     c92     c93     c94     c95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 6  5.9440 -2.1670  ...  0.1855  1.1720  0.8325  0.6486  0.8090  1.5880
# 7  2.5950  0.6980  ...  0.3230 -0.4140  0.2532  0.0513  0.8600  1.4250
#
#       c96     c97     c98     c99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %%
# Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot)

# %%
dados['dose'].value_counts().plot.bar(color="purple", ec="black", alpha=0.4)

plt.title('DOSES')
plt.xlabel('Tipos de doses')
plt.ylabel('Quantidade de experimentos')
plt.figure(figsize=(10,7))

# %%
# Desafio 08: Resumo do que você aprendeu com os dados

# %%
# Foi ótimo

# %%
# --

# %%
dados
# Out:
#                  id    tratamento  tempo dose      droga      g0      g1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 3      id_0015fd391     com_droga     48   D1  8c7f86626 -0.5138 -0.2491
# 4      id_001626bd3     com_droga     72   D2  7cbed3131 -0.3254 -0.4009
# ...             ...           ...    ...  ...        ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#            g2      g3      g4  ...     c90     c91     c92     c93     c94  \
# ...

# %%
mapa = {'droga':'composto'}
dados.rename(columns=mapa, inplace=True) #precisa do inplace para ser definitivo

# %%
dados.head()
# Out:
#              id tratamento  tempo dose   composto      g0      g1      g2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  com_droga     72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#        g3      g4  ...     c90     c91     c92     c93     c94     c95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#       c96     c97     c98     c99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %%
dados
# Out:
#                  id    tratamento  tempo dose   composto      g0      g1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 3      id_0015fd391     com_droga     48   D1  8c7f86626 -0.5138 -0.2491
# 4      id_001626bd3     com_droga     72   D2  7cbed3131 -0.3254 -0.4009
# ...             ...           ...    ...  ...        ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#            g2      g3      g4  ...     c90     c91     c92     c93     c94  \
# ...

# %%
compostos = dados['composto'].value_counts().index[:5]

# %%
compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @compostos')
# Out:
#                  id    tratamento  tempo dose   composto      g0      g1  \
# 7      id_0020d0484     com_droga     48   D1  8b87a7a83  0.2711  0.5133
# 16     id_002fb9c19     com_droga     48   D1  87d714366  8.7380  0.1914
# 25     id_0054388ec  com_controle     48   D1  cacb2b860 -0.6696 -0.2718
# 38     id_0079af0fb  com_controle     24   D1  cacb2b860 -0.1636 -1.8230
# 40     id_007bfbb91  com_controle     24   D2  cacb2b860 -1.3200 -1.7340
# ...             ...           ...    ...  ...        ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  cacb2b860  0.6008  0.2781
# 23802  id_fff3976bd     com_droga     24   D1  87d714366  3.2890  2.1270
# 23805  id_fff6df1c5     com_droga     48   D2  5628cb3ee  1.7380 -1.2900
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
#
#            g2      g3      g4  ...     c90     c91     c92     c93     c94  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (9, 7))

sns.set() #padrão seaborn

ax = sns.countplot(x = 'composto', data=dados.query('composto in @compostos'))

ax.set_title('Top 5 compostos')

plt.show() #some o texto q tem logo a cima do gráfico

# %%
len(dados['g0'].unique())
# Out:
# 14367

# %%
dados['g0'].min()
# Out:
# -5.513

# %%
dados['g0'].max()
# Out:
# 10.0

# %%
dados['g0'].hist(bins = 100)

plt.show()

# %%
dados['g19'].hist(bins = 100)

plt.show()

# %%
dados.describe()
# Out:
#               tempo            g0            g1            g2            g3  \
# count  23814.000000  23814.000000  23814.000000  23814.000000  23814.000000
# mean      48.020156      0.248366     -0.095684      0.152253      0.081971
# std       19.402807      1.393399      0.812363      1.035731      0.950012
# min       24.000000     -5.513000     -5.737000     -9.104000     -5.998000
# 25%       24.000000     -0.473075     -0.562200     -0.437750     -0.429575
# 50%       48.000000     -0.008850     -0.046600      0.075200      0.008050
# 75%       72.000000      0.525700      0.403075      0.663925      0.463400
# max       72.000000     10.000000      5.039000      8.257000     10.000000
#
#                  g4            g5            g6            g7            g8  \
# count  23814.000000  23814.000000  23814.000000  23814.000000  23814.000000
# mean       0.057347     -0.138836      0.035961     -0.202651     -0.190083
# ...

# %%
dados[['g0', 'g1']]
# Out:
#            g0      g1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
dados.loc[:, 'g0': 'g771'].describe()
# Out:
#                  g0            g1            g2            g3            g4  \
# count  23814.000000  23814.000000  23814.000000  23814.000000  23814.000000
# mean       0.248366     -0.095684      0.152253      0.081971      0.057347
# std        1.393399      0.812363      1.035731      0.950012      1.032091
# min       -5.513000     -5.737000     -9.104000     -5.998000     -6.369000
# 25%       -0.473075     -0.562200     -0.437750     -0.429575     -0.470925
# 50%       -0.008850     -0.046600      0.075200      0.008050     -0.026900
# 75%        0.525700      0.403075      0.663925      0.463400      0.465375
# max       10.000000      5.039000      8.257000     10.000000     10.000000
#
#                  g5            g6            g7            g8            g9  \
# count  23814.000000  23814.000000  23814.000000  23814.000000  23814.000000
# mean      -0.138836      0.035961     -0.202651     -0.190083      0.119905
# ...

# %%
dados.loc[:, 'g0': 'g771'].describe().T
# Out:
#         count      mean       std     min       25%      50%       75%     max
# g0    23814.0  0.248366  1.393399  -5.513 -0.473075 -0.00885  0.525700  10.000
# g1    23814.0 -0.095684  0.812363  -5.737 -0.562200 -0.04660  0.403075   5.039
# g2    23814.0  0.152253  1.035731  -9.104 -0.437750  0.07520  0.663925   8.257
# g3    23814.0  0.081971  0.950012  -5.998 -0.429575  0.00805  0.463400  10.000
# g4    23814.0  0.057347  1.032091  -6.369 -0.470925 -0.02690  0.465375  10.000
# ...       ...       ...       ...     ...       ...      ...       ...     ...
# g767  23814.0 -0.076251  1.115477 -10.000 -0.506200  0.00990  0.511175   6.317
# g768  23814.0  0.134162  0.951264  -4.269 -0.353100  0.00540  0.409075  10.000
# g769  23814.0 -0.128018  1.230636 -10.000 -0.544600  0.00060  0.498500   5.911
# g770  23814.0 -0.219210  1.326193 -10.000 -0.554400  0.02870  0.496400  10.000
# g771  23814.0  0.101524  1.417674 -10.000 -0.523800 -0.00650  0.536950  10.000
#
# [772 rows x 8 columns]

# %%
dados.loc[:, 'g0': 'g771'].describe().T['mean'].hist(bins = 30)
# Out:
# <AxesSubplot:>

# %%
dados.loc[:, 'g0': 'g771'].describe().T['min'].hist(bins = 30)
# Out:
# <AxesSubplot:>

# %%
dados.loc[:, 'g0': 'g771'].describe().T['max'].hist(bins = 30)
# Out:
# <AxesSubplot:>

# %%
dados.loc[:, 'c0': 'c99'].describe().T['mean'].hist(bins = 50)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x = 'g0', data=dados)

plt.show()

# %%
sns.boxplot(x = 'g0', y = 'tratamento', data=dados)

plt.show()

# %%
sns.boxplot(y = 'g0', x = 'tratamento', data=dados)

plt.show()

# %%
# Desafio 01: Ordenar o gráfico countplot

# %%
sns.set()

plt.show()

plt.figure(figsize=(8,6))

ax = sns.countplot(x = 'composto', order = compostos, data=dados.query('composto in @compostos'))

ax.set_title('Top 5 compostos')
# Out:
# Text(0.5, 1.0, 'Top 5 compostos')

# %%
# Desafio 02: Melhorar o gráfico

# %%
sns.set()

plt.figure(figsize=(8,6))

ax = sns.countplot(x = 'composto', order = compostos, palette="Set3", edgecolor='.5', data=dados.query('composto in @compostos'))

ax.set_title('Top 5 compostos', fontsize=20)

plt.xlabel('Compostos', fontsize=18)

plt.ylabel('Quantidades', fontsize=18)

plt.show()

# %%
# Desafio 03: Plotar os histogramas com seaborn

# %%
plt.figure(figsize=(12,9))

plt.xlabel('Faixa de valores', fontsize=20)

plt.ylabel('Quantidades', fontsize=20)

plt.title('Gene 17', fontsize=30)

sns.histplot(data=dados['g17'], bins=32, edgecolor='.5', color = 'purple', kde=True)

plt.show()

# %%
# Desafio 04: Estudar sobre as estatísticas retornadas no .describe()

# %%
dados.describe()
# Out:
#               tempo            g0            g1            g2            g3  \
# count  23814.000000  23814.000000  23814.000000  23814.000000  23814.000000
# mean      48.020156      0.248366     -0.095684      0.152253      0.081971
# std       19.402807      1.393399      0.812363      1.035731      0.950012
# min       24.000000     -5.513000     -5.737000     -9.104000     -5.998000
# 25%       24.000000     -0.473075     -0.562200     -0.437750     -0.429575
# 50%       48.000000     -0.008850     -0.046600      0.075200      0.008050
# 75%       72.000000      0.525700      0.403075      0.663925      0.463400
# max       72.000000     10.000000      5.039000      8.257000     10.000000
#
#                  g4            g5            g6            g7            g8  \
# count  23814.000000  23814.000000  23814.000000  23814.000000  23814.000000
# mean       0.057347     -0.138836      0.035961     -0.202651     -0.190083
# ...

# %%
# count: é a quantidade de elementos
# mean: é a média dos valores
# std: é o desvio padrão, que descreve como os dados estão dispersos ao redor da média
# min: é o valor mínimo
# 25 %: é o elemento do primeiro quartil
# 50 %: é o elemento do segundo quartil (ou mediana)
# 70 %: é o elemento do terceiro quartil
# max: é o valor máximo

# %%
# Desafio 05: Refletir sobre a manipulação do tamanho das visualizações

# %%
# --

# %%
# Desafio 06: Fazer outras análises com o boxplot e até com o histograma

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 8))

sns.histplot(data=dados['g12'], bins= 50, kde=True, color='red', edgecolor='.3')

plt.xlabel('G-12', fontsize=25)

plt.ylabel('Quantidades', fontsize=25)


plt.show()

# %%
plt.figure(figsize=(9, 7))

sns.boxplot(data=dados['g12'])

plt.xlabel('Tratamento', fontsize=20)

plt.ylabel('G-12', fontsize=20)

sns.despine(offset=8)

plt.show()

# %%
# Desafio 07: Resumo do que você aprendeu com os dados

# %%
# Foi ótimo

# %%
# ---

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize=True)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.012640   0.150542
#      48         0.014403   0.168430
#      72         0.012892   0.151172
# D2   24         0.012808   0.150374
#      48         0.012808   0.150794
#      72         0.012808   0.150332

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
dados[['g0', 'g3']]
# Out:
#            g0      g3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot(x='g0', y='g3', data=dados)

plt.show()

# %%
sns.scatterplot(x='g0', y='g8', data=dados)

plt.show()

# %%
sns.lmplot(x='g0', y='g8', data=dados, line_kws={'color':'red'})

# %%
sns.lmplot(x='g0', y='g8', data=dados, line_kws={'color':'red'}, col='tratamento', row='tempo')

plt.show()

# %%
dados.loc[:, 'g0' : 'g771'].corr()
# Out:
#             g0        g1        g2        g3        g4        g5        g6  \
# g0    1.000000  0.086032  0.176188  0.011266  0.403153 -0.165478  0.238348
# g1    0.086032  1.000000 -0.054518 -0.027855  0.193647 -0.151590 -0.122541
# g2    0.176188 -0.054518  1.000000  0.042633  0.013968  0.018516  0.015190
# g3    0.011266 -0.027855  0.042633  1.000000 -0.033039  0.042231 -0.043177
# g4    0.403153  0.193647  0.013968 -0.033039  1.000000 -0.057449  0.206405
# ...        ...       ...       ...       ...       ...       ...       ...
# g767 -0.052622 -0.003378 -0.053149 -0.179370  0.124425 -0.081016 -0.000886
# g768  0.300241 -0.030756  0.115415  0.028452  0.115579 -0.139000 -0.005791
# g769 -0.127375 -0.006866  0.014489 -0.206077 -0.172727 -0.068537 -0.278587
# g770 -0.514201 -0.095108 -0.078661 -0.002142 -0.363673  0.144631 -0.143428
# g771  0.405908 -0.032233  0.103985  0.058219  0.250713 -0.093237  0.075019
#
# ...

# %%
corr_celular = dados.loc[:, 'g0' : 'g50'].corr()

# %%
import numpy as np

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(17, 15))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
corr_celular = dados.loc[:, 'c0' : 'c50'].corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(17, 15))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
# Desafio 01: Criar tabelas de frequência com pandas.groupby()

# %%
teste = dados.groupby(['tratamento', 'dose'])

# %%
teste.count()
# Out:
#                       id  tempo  composto     g0     g1     g2     g3     g4  \
# tratamento   dose
# com_controle D1      951    951       951    951    951    951    951    951
#              D2      915    915       915    915    915    915    915    915
# com_droga    D1    11196  11196     11196  11196  11196  11196  11196  11196
#              D2    10752  10752     10752  10752  10752  10752  10752  10752
#
#                       g5     g6  ...    c90    c91    c92    c93    c94  \
# tratamento   dose                ...
# com_controle D1      951    951  ...    951    951    951    951    951
#              D2      915    915  ...    915    915    915    915    915
# com_droga    D1    11196  11196  ...  11196  11196  11196  11196  11196
#              D2    10752  10752  ...  10752  10752  10752  10752  10752
#
#                      c95    c96    c97    c98    c99
# tratamento   dose
# com_controle D1      951    951    951    951    951
# ...

# %%
teste2 = dados.groupby(['tratamento', 'dose', 'tempo', 'composto'])

# %%
teste2.count()
# Out:
#                                     id   g0   g1   g2   g3   g4   g5   g6  \
# tratamento   dose tempo composto
# com_controle D1   24    cacb2b860  301  301  301  301  301  301  301  301
#                   48    cacb2b860  343  343  343  343  343  343  343  343
#                   72    cacb2b860  307  307  307  307  307  307  307  307
#              D2   24    cacb2b860  305  305  305  305  305  305  305  305
#                   48    cacb2b860  305  305  305  305  305  305  305  305
# ...                                ...  ...  ...  ...  ...  ...  ...  ...
# com_droga    D2   72    ff5a3ecb1    1    1    1    1    1    1    1    1
#                         ff9565933    1    1    1    1    1    1    1    1
#                         ffd66e220    1    1    1    1    1    1    1    1
#                         ffed8e1c9    1    1    1    1    1    1    1    1
#                         fff7d208d    1    1    1    1    1    1    1    1
#
# ...

# %%
# Desafio 02: Normalizar o crosstab pela coluna

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %%
# Desafio 03: Explorar outros agregadores

# %%
pd.crosstab([dados['dose'] , dados['tempo']] , dados['tratamento'] , values=dados.g0 , aggfunc='describe')
# Out:
#                     25%                    50%                    75%  \
# tratamento com_controle com_droga com_controle com_droga com_controle
# dose tempo
# D1   24        -0.75280 -0.436800      -0.2912   0.02700      0.18600
#      48        -0.62700 -0.475700      -0.2145   0.01620      0.38160
#      72        -0.84755 -0.470725      -0.3655   0.02615      0.19925
# D2   24        -0.56540 -0.519200       0.0096  -0.02610      0.56950
#      48        -0.47120 -0.428200      -0.0506  -0.02960      0.42590
#      72        -0.44030 -0.452550       0.0528   0.00015      0.58420
#
#                             count                    max            \
# tratamento com_droga com_controle com_droga com_controle com_droga
# dose tempo
# D1   24      0.58860        301.0    3585.0        3.226     9.908
#      48      0.64860        343.0    4011.0        3.423    10.000
#      72      0.54780        307.0    3600.0        2.584     9.355
# ...

# %%
# Desafio 04: Explorar o melt

# %%
pd.melt(dados, id_vars=['dose'], value_vars=['tempo'], var_name='Tempo', value_name='Valor')
# Out:
#       dose  Tempo  Valor
# 0       D1  tempo     24
# 1       D1  tempo     72
# 2       D1  tempo     48
# 3       D1  tempo     48
# 4       D2  tempo     72
# ...    ...    ...    ...
# 23809   D2  tempo     24
# 23810   D2  tempo     24
# 23811   D2  tempo     48
# 23812   D1  tempo     24
# 23813   D1  tempo     72
#
# [23814 rows x 3 columns]

# %%
# Desafio 05: Calcular e analisar a correlação entre os G's e os C's. Refletir sobre os efeitos biológicos

# %%
# ---

# %%
# Desafio 06: Estudar o código que plota a matriz de correlação (heatmap)

# %%
corr_celular = dados.loc[:,'g0':'g50'].corr()

# %%
#Plot com mascara

mask = np.triu(np.ones_like(corr_celular, dtype=bool))

f, ax = plt.subplots(figsize=(17, 15))

cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

#Plot sem mascara

f, ax = plt.subplots(figsize=(17, 15))

cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr_celular, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
# Desafio 07: Resumo do que você aprendeu com os dados

# %%
# ---
